# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidence to answer the following questions.
#
# 1. How many neighborhood groups are there and which shows up the most?
# 2. Are private rooms the most popular in Manhattan?
# 3. Who are the top 10 busiest hosts based on number of reviews per month?
# 4. Which neighorhood group has the highest average price? Plot the average prices in a professional looking bar chart
# 5. What is the most expensive neighbourhood in each neighbourhood group?
# 6. Which host has the highest minimum rental? *minimal rental is based on price and minimum nights
# 7. Who currently has no (zero) availability with a review count of 100 or more?
# 8. If each host rents all of their properties for the night, which 5 make the most that night?
# 9. When did Danielle from Queens last receive a review?
# 10. Display a bar chart showing the number of each type of room in the Bronx
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this entire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to simulate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('./AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
# How many neighbourhood groups / which shows up the most
neighbourhoods = air_bnb.groupby('neighbourhood_group').count()['id'].sort_values(ascending=False)
most = pd.DataFrame(neighbourhoods)
most
# Out:
#                         id
# neighbourhood_group
# Manhattan            21661
# Brooklyn             20104
# Queens                5666
# Bronx                 1091
# Staten Island          373

# %%
# Are private rooms the most popular in Manhattan?
manhattan_bnb = air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan']
most_pop = manhattan_bnb.groupby('room_type').count()['id'].sort_values(ascending=False)
pop = pd.DataFrame(most_pop)
pop
# Out:
#                     id
# room_type
# Entire home/apt  13199
# Private room      7982
# Shared room        480

# %%
# Who are the top 10 busiest hosts based on number of reviews per month?
reviews = air_bnb.groupby(['host_id', 'host_name']).sum()['reviews_per_month'].nlargest(10)
busiest = pd.DataFrame(reviews)
busiest
# Out:
#                                           reviews_per_month
# host_id   host_name
# 219517861 Sonder (NYC)                               397.56
# 244361589 Row NYC                                    111.72
# 232251881 Lakshmee                                    80.63
# 26432133  Danielle                                    68.02
# 137274917 David                                       62.89
# 224414117 Gabriel                                     59.10
# 156948703 Asad                                        56.44
# 344035    Brooklyn&   Breakfast    -Len-              56.00
# 156684502 Nalicia                                     54.38
# 37312959  Maya                                        53.53

# %%
# Which neighborhood group has the highest avg price and plot the average prices in a bar chart
average_prices = air_bnb.groupby('neighbourhood_group').mean()['price'].nlargest()
average_prices
# Out:
# neighbourhood_group
# Manhattan        196.875814
# Brooklyn         124.383207
# Staten Island    114.812332
# Queens            99.517649
# Bronx             87.496792
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.bar(average_prices.index, average_prices, color=['g', 'b', 'k', 'y', 'r'])
plt.title('Average Price Per NY Borough', fontname='Courier', fontsize=28)
plt.grid(True)
plt.ylabel('Average Price', fontname='Courier', fontsize='22')
plt.xlabel('Borough', fontname='Courier', fontsize='22')
plt.show()

# %%
# What is the most expensive neighbourhood in each neighbourhood_group
group_average = air_bnb.groupby(['neighbourhood_group', 'neighbourhood']).mean()
group_average
# Out:
#                                              id       host_id   latitude  \
# neighbourhood_group neighbourhood
# Bronx               Allerton       2.007729e+07  1.052045e+08  40.865292
#                     Baychester     2.215566e+07  1.391305e+08  40.873616
#                     Belmont        2.690317e+07  1.468852e+08  40.855062
#                     Bronxdale      2.190473e+07  1.105278e+08  40.854731
#                     Castle Hill    3.304754e+07  2.257518e+08  40.816889
# ...                                         ...           ...        ...
# Staten Island       Tottenville    1.823501e+07  7.724669e+07  40.507350
#                     West Brighton  1.885742e+07  6.569042e+07  40.631932
#                     Westerleigh    2.070684e+07  1.482153e+08  40.613895
#                     Willowbrook    2.708802e+07  1.158272e+08  40.598860
#                     Woodrow        1.798271e+06  9.430973e+06  40.538840
#
#                                    longitude       price  minimum_nights  \
# neighbourhood_group neighbourhood
# Bronx               Allerton      -73.858727   87.595238        2.214286
#                     Baychester    -73.842967   75.428571        2.428571
#                     Belmont       -73.887109   77.125000        3.375000
#                     Bronxdale     -73.866287   57.105263        2.894737
#                     Castle Hill   -73.847000   63.000000        2.333333
# ...                                      ...         ...             ...
# Staten Island       Tottenville   -74.239390  144.857143        2.428571
#                     West Brighton -74.115959   80.555556        5.166667
#                     Westerleigh   -74.133665   71.500000        2.500000
#                     Willowbrook   -74.132170  249.000000        4.000000
#                     Woodrow       -74.198260  700.000000        7.000000
#
#                                    number_of_reviews  reviews_per_month  \
# neighbourhood_group neighbourhood
# Bronx               Allerton               42.928571           1.834054
#                     Baychester             44.285714           2.206667
#                     Belmont                12.333333           1.888000
#                     Bronxdale              24.105263           1.916875
#                     Castle Hill            13.111111           2.775000
# ...                                              ...                ...
# Staten Island       Tottenville            19.857143           1.146000
#                     West Brighton          36.444444           1.443750
#                     Westerleigh             9.000000           0.505000
#                     Willowbrook             9.000000           0.800000
#                     Woodrow                 0.000000                NaN
#
#                                    calculated_host_listings_count  \
# neighbourhood_group neighbourhood
# Bronx               Allerton                             2.761905
#                     Baychester                           1.714286
#                     Belmont                              1.583333
#                     Bronxdale                            1.105263
#                     Castle Hill                          5.666667
# ...                                                           ...
# Staten Island       Tottenville                          1.285714
#                     West Brighton                        2.888889
#                     Westerleigh                          1.000000
#                     Willowbrook                          2.000000
#                     Woodrow                              1.000000
#
#                                    availability_365
# neighbourhood_group neighbourhood
# Bronx               Allerton             163.666667
#                     Baychester           157.857143
#                     Belmont              187.666667
#                     Bronxdale            145.421053
#                     Castle Hill          159.333333
# ...                                             ...
# Staten Island       Tottenville          267.571429
#                     West Brighton        274.722222
#                     Westerleigh          112.500000
#                     Willowbrook          351.000000
#                     Woodrow                0.000000
#
# [221 rows x 10 columns]

# %%
bronx_high = group_average.loc['Bronx'].nlargest(1, 'price')
bronx_high
# Out:
#                        id       host_id   latitude  longitude       price  \
# neighbourhood
# Riverdale      18602901.0  6.890678e+07  40.887352 -73.912064  442.090909
#
#                minimum_nights  number_of_reviews  reviews_per_month  \
# neighbourhood
# Riverdale            5.363636          26.636364               1.32
#
#                calculated_host_listings_count  availability_365
# neighbourhood
# Riverdale                            1.545455        160.818182

# %%
manhattan_high = group_average.loc['Manhattan'].nlargest(1, 'price')
manhattan_high
# Out:
#                          id       host_id   latitude  longitude       price  \
# neighbourhood
# Tribeca        1.969456e+07  5.274450e+07  40.717744   -74.0074  490.638418
#
#                minimum_nights  number_of_reviews  reviews_per_month  \
# neighbourhood
# Tribeca             11.378531          11.491525           0.834909
#
#                calculated_host_listings_count  availability_365
# neighbourhood
# Tribeca                             42.971751        126.508475

# %%
brooklyn_high = group_average.loc['Brooklyn'].nlargest(1, 'price')
brooklyn_high
# Out:
#                          id       host_id   latitude  longitude       price  \
# neighbourhood
# Sea Gate       2.017955e+07  1.168665e+08  40.577119  -74.00872  487.857143
#
#                minimum_nights  number_of_reviews  reviews_per_month  \
# neighbourhood
# Sea Gate             4.142857           1.428571               0.33
#
#                calculated_host_listings_count  availability_365
# neighbourhood
# Sea Gate                             1.857143         65.571429

# %%
queens_high = group_average.loc['Queens'].nlargest(1, 'price')
queens_high
# Out:
#                        id     host_id  latitude  longitude       price  \
# neighbourhood
# Neponsit       17287932.0  97088229.0  40.57063 -73.859217  274.666667
#
#                minimum_nights  number_of_reviews  reviews_per_month  \
# neighbourhood
# Neponsit                  2.0          15.333333                1.6
#
#                calculated_host_listings_count  availability_365
# neighbourhood
# Neponsit                                  1.0             231.0

# %%
staten_island_high = group_average.loc['Staten Island'].nlargest(1, 'price')
staten_island_high
# Out:
#                         id    host_id  latitude  longitude  price  \
# neighbourhood
# Fort Wadsworth  20305160.0  1715301.0  40.59546  -74.06092  800.0
#
#                 minimum_nights  number_of_reviews  reviews_per_month  \
# neighbourhood
# Fort Wadsworth             7.0                0.0                NaN
#
#                 calculated_host_listings_count  availability_365
# neighbourhood
# Fort Wadsworth                             3.0             365.0

# %%
# Which host has the highest minimum rental? *minimal rental is based on price and minimum nights
air_bnb['minimum_rental'] = air_bnb['minimum_nights'] * air_bnb['price']
air_bnb.nlargest(5, 'minimum_rental')
# Out:
#              id                                             name   host_id  \
# 9151    7003697              Furnished room in Astoria apartment  20582832
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                              1-BR Lincoln Center  72390391
# 6530    4737930                               Spanish Harlem Apt   1235070
# 12342   9528920              Quiet, Clean, Lit @ LES & Chinatown   3906464
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
# 6530      Olson           Manhattan      East Harlem  40.79264  -73.93898
# 12342       Amy           Manhattan  Lower East Side  40.71355  -73.98507
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 9151      Private room  10000           10000                  2  2016-02-13
# 17692  Entire home/apt  10000           10000                  5  2017-07-27
# 29238  Entire home/apt  10000           10000                  0         NaN
# 6530   Entire home/apt   9999            9999                  1  2015-01-02
# 12342     Private room   9999            9999                  6  2016-01-01
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 9151                0.04                               1                 0
# 17692               0.16                               1                 0
# 29238                NaN                               1                83
# 6530                0.02                               1                 0
# 12342               0.14                               1                83
#
#        minimum_rental
# 9151        100000000
# 17692       100000000
# 29238       100000000
# 6530         99980001
# 12342        99980001

# %%
air_bnb[['host_name', 'minimum_nights', 'price']].nlargest(10, ['price'], keep='last').sort_values('minimum_nights').head(1)
# Out:
#       host_name  minimum_nights  price
# 45666    Sandra            7500   7500

# %%
# Who has no (zero) availability with a review count of 100 or more
air_bnb[(air_bnb['availability_365']== 0) & (air_bnb['number_of_reviews'] >= 100)]
# Out:
#              id                                       name    host_id  \
# 8          5203         Cozy Clean Guest Room - Family Apt       7490
# 94        20913         Charming 1 bed GR8 WBurg LOCATION!      79402
# 132       30031           NYC artists’ loft with roof deck     129352
# 174       44221             Financial District Luxury Loft     193722
# 180       45556      Fort Greene, Brooklyn: Center Bedroom      67778
# ...         ...                                        ...        ...
# 29581  22705516         The Quietest Block in Manhattan :)  127740507
# 30461  23574142                          queens get away!!  176185168
# 31250  24267706  entire sunshine of the spotless mind room   21074914
# 32670  25719044                COZY Room for Female Guests   40119874
# 35014  27759146     Cozy corner near Empire State Building  209549523
#
#         host_name neighbourhood_group              neighbourhood  latitude  \
# 8       MaryEllen           Manhattan            Upper West Side  40.80178
# 94     Christiana            Brooklyn               Williamsburg  40.70984
# 132           Sol            Brooklyn                 Greenpoint  40.73494
# 174         Coral           Manhattan         Financial District  40.70666
# 180          Doug            Brooklyn                Fort Greene  40.68863
# ...           ...                 ...                        ...       ...
# 29581    Kathleen           Manhattan                     Harlem  40.83102
# 30461       Janet              Queens                  Laurelton  40.68209
# 31250      Albert            Brooklyn         Bedford-Stuyvesant  40.68234
# 32670    Stephany            Brooklyn  Prospect-Lefferts Gardens  40.66242
# 35014     Mariluz           Manhattan                    Midtown  40.74858
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 8      -73.96723     Private room     79              79                118
# 94     -73.95775  Entire home/apt    100             100                168
# 132    -73.95030     Private room     50              50                193
# 174    -74.01374  Entire home/apt    196             196                114
# 180    -73.97691     Private room     65              65                206
# ...          ...              ...    ...             ...                ...
# 29581  -73.94181     Private room     65              65                103
# 30461  -73.73662     Private room     65              65                119
# 31250  -73.91318     Private room     49              49                102
# 32670  -73.94417     Private room     48              48                131
# 35014  -73.98341      Shared room     62              62                112
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 8      2017-07-21               0.99                               1
# 94     2018-07-22               1.57                               1
# 132    2019-05-20               1.86                               1
# 174    2019-06-20               1.06                               1
# 180    2019-06-30               1.92                               2
# ...           ...                ...                             ...
# 29581  2019-07-07               5.89                               2
# 30461  2018-12-24               7.79                               1
# 31250  2019-07-05               6.73                               3
# 32670  2019-05-31               9.97                               2
# 35014  2019-06-13              10.77                               3
#
#        availability_365  minimum_rental
# 8                     0            6241
# 94                    0           10000
# 132                   0            2500
# 174                   0           38416
# 180                   0            4225
# ...                 ...             ...
# 29581                 0            4225
# 30461                 0            4225
# 31250                 0            2401
# 32670                 0            2304
# 35014                 0            3844
#
# [162 rows x 17 columns]

# %%
# If each host rents all of their properties for the night, which 5 make the most that night?
air_bnb.groupby(['host_id', 'host_name']).sum().nlargest(5, 'price')
# Out:
#                                  id     latitude    longitude  price  \
# host_id   host_name
# 219517861 Sonder (NYC)  10885561678  13316.25823 -24198.18856  82795
# 107434423 Blueground     7210036953   9451.60418 -17166.13165  70331
# 156158778 Sally           332529233    488.73929   -887.71735  37097
# 205031545 Red Awning     1415225676   1996.92821  -3624.34656  35294
# 30283594  Kara           1611854192   4931.41347  -8952.50779  33581
#
#                         minimum_nights  number_of_reviews  reviews_per_month  \
# host_id   host_name
# 219517861 Sonder (NYC)           82795               1281             397.56
# 107434423 Blueground             70331                 29               6.04
# 156158778 Sally                  37097                  1               1.00
# 205031545 Red Awning             35294                127              21.21
# 30283594  Kara                   33581                 65               3.94
#
#                         calculated_host_listings_count  availability_365  \
# host_id   host_name
# 219517861 Sonder (NYC)                          106929             98588
# 107434423 Blueground                             53824             58884
# 156158778 Sally                                    144               776
# 205031545 Red Awning                              2401             10796
# 30283594  Kara                                   14641             37924
#
#                         minimum_rental
# host_id   host_name
# 219517861 Sonder (NYC)        25625473
# 107434423 Blueground          22009543
# 156158778 Sally              161606073
# 205031545 Red Awning          25621762
# 30283594  Kara                12353607

# %%
# When did Danielle from Queens last receive a review?
air_bnb[(air_bnb['host_name'] == 'Danielle') & (air_bnb['neighbourhood_group'] == 'Queens')].groupby('host_id').max()
# Out:
#                  id                                               name  \
# host_id
# 18051286   13151075                    ASTORIA APARTMENT OUTDOOR SPACE
# 26432133   18173787   Sun Room Family Home LGA Airport NO CLEANING FEE
# 154256662  21386105  Quiet & clean 1br haven with balcony near the ...
# 201647469  26814763  One bedroom with full bed / 1 stop from Manhattan
#
#           host_name neighbourhood_group     neighbourhood  latitude  \
# host_id
# 18051286   Danielle              Queens           Astoria  40.77221
# 26432133   Danielle              Queens     East Elmhurst  40.76389
# 154256662  Danielle              Queens           Astoria  40.77134
# 201647469  Danielle              Queens  Long Island City  40.74565
#
#            longitude        room_type  price  minimum_nights  \
# host_id
# 18051286   -73.92901     Private room     50              50
# 26432133   -73.87007      Shared room     54              54
# 154256662  -73.92424  Entire home/apt    250             250
# 201647469  -73.94699     Private room    108             108
#
#            number_of_reviews last_review  reviews_per_month  \
# host_id
# 18051286                   0         NaN                NaN
# 26432133                 510  2019-07-08              16.22
# 154256662                  1  2018-01-02               0.05
# 201647469                 13  2019-06-20               1.74
#
#            calculated_host_listings_count  availability_365  minimum_rental
# host_id
# 18051286                                1                 0            2500
# 26432133                                5               347            2916
# 154256662                               1               180           62500
# 201647469                               1               333           11664

# %%
# bar chart showing the number of room types in the Bronx
bronx_bnb = air_bnb[air_bnb['neighbourhood_group'] == 'Bronx']
room_count = bronx_bnb.groupby('room_type').count()['id']
room_count
# Out:
# room_type
# Entire home/apt    379
# Private room       652
# Shared room         60
# Name: id, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.bar(room_count.index, room_count, color=['r', 'g', 'b'])
plt.title('Number of Rooms Per Room Type in the Bronx', fontname='Sans Serif', fontsize=28)
plt.xlabel('Room Type', fontsize=20)
plt.ylabel('Number of Rooms', fontsize=20)
plt.show()

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
